# %%
# ipynb파일을 작성하고, 이떄 확장프로그램으로 jupyter notebook 설치
# 파일-다른이름으로 저장 - app.ipynb로 저장
# 하면 화면 왼쪽의 탐색기에 보임
# 하지만 git에는 보이지 않음
print(1)
# Out:
# 1

# %%
# 작업이 끝나면 git repo에 올려야함(push)
# 터미널에서
# git add app.ipynb
# git commit -m "Add: notebook file"
# git push
